# %% [markdown]
# <a href="https://colab.research.google.com/github/PritamRoutray111/Advertising_Regression_model/blob/main/Advertising_sales_prediction_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#importing all the libreries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/content/Advertising.csv',index_col=0)

# %%
df.head()
# Out:
#       TV  radio  newspaper  sales
# 1  230.1   37.8       69.2   22.1
# 2   44.5   39.3       45.1   10.4
# 3   17.2   45.9       69.3    9.3
# 4  151.5   41.3       58.5   18.5
# 5  180.8   10.8       58.4   12.9

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 200 entries, 1 to 200
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TV         200 non-null    float64
#  1   radio      200 non-null    float64
#  2   newspaper  200 non-null    float64
#  3   sales      200 non-null    float64
# dtypes: float64(4)
# memory usage: 7.8 KB

# %%
df.describe()
# Out:
#                TV       radio   newspaper       sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   14.022500
# std     85.854236   14.846809   21.778621    5.217457
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   10.375000
# 50%    149.750000   22.900000   25.750000   12.900000
# 75%    218.825000   36.525000   45.100000   17.400000
# max    296.400000   49.600000  114.000000   27.000000

# %%
df.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
 cols=df.columns
 cols
# Out:
# Index(['TV', 'radio', 'newspaper', 'sales'], dtype='object')

# %%
for i in cols:
  sns.boxplot(df[i])
  plt.show()

# %%
x=df[['TV', 'radio', 'newspaper']]
y=df['sales']

# %%
x
# Out:
#         TV  radio  newspaper
# 1    230.1   37.8       69.2
# 2     44.5   39.3       45.1
# 3     17.2   45.9       69.3
# 4    151.5   41.3       58.5
# 5    180.8   10.8       58.4
# ..     ...    ...        ...
# 196   38.2    3.7       13.8
# 197   94.2    4.9        8.1
# 198  177.0    9.3        6.4
# 199  283.6   42.0       66.2
# 200  232.1    8.6        8.7
#
# [200 rows x 3 columns]

# %%
y
# Out:
# 1      22.1
# 2      10.4
# 3       9.3
# 4      18.5
# 5      12.9
#        ...
# 196     7.6
# 197     9.7
# 198    12.8
# 199    25.5
# 200    13.4
# Name: sales, Length: 200, dtype: float64

# %%
from sklearn.model_selection import train_test_split
# Correct the order of the variables assigned from train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=10)

# %%
from sklearn.linear_model import LinearRegression
alpha=LinearRegression()
alpha.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred= alpha.predict(x_test)

# %%
y_pred
# Out:
# array([18.1625299 , 12.92663232, 18.0531098 , 23.64464668, 20.70438374,
#        14.28227997, 14.94493548, 21.38232981, 21.17508238, 12.73110461,
#        24.00312134,  7.21544071, 12.24762152, 19.24345998, 19.38241854,
#        13.45643798, 19.6247089 ,  9.2531648 , 21.13268075, 20.90762408,
#        15.53485445, 10.92529369, 22.82955184, 15.8122438 , 17.42515749,
#         8.16218669, 11.89783444, 12.70337575, 21.74138085,  7.96215368,
#        12.50099965, 20.45535282,  4.72120047,  4.72259288, 16.75292333,
#        15.75804986,  6.74415499, 17.73477354,  9.01591827, 13.617599  ])

# %%
from sklearn.metrics import r2_score
R2_score=r2_score(y_test,y_pred)
R2_score*100
# Out:
# 83.53672324670593

# %%
plt.scatter(y_test,y_pred)
plt.title('Actual vs Predicted')
plt.xlabel('Actual_values')
plt.ylabel('Predicted_values')
plt.plot([min(y_test),max(y_test)],[min(y_test),max(y_test)])
plt.show()
